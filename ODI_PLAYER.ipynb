# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/ODI Player Innings Stats - All Teams.csv.zip")
df
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1,2,3,6,7,8,9,17,18,20,21,22,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#             Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0                   JJ Roy                 180                     180
# 1                 AD Hales                 171                     171
# 2                 RA Smith                167*                     167
# 3                   JJ Roy                 162                     162
# 4                 DI Gower                 158                     158
# ...                    ...                 ...                     ...
# 171963  Samiullah Shinwari                 NaN                     NaN
# 171964       Asghar Afghan                 NaN                     NaN
# 171965   Najibullah Zadran                 NaN                     NaN
# 171966         Rahmat Shah                 NaN                     NaN
# 171967       Ikram Alikhil                 NaN                     NaN
#
#        Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                         151                  1.0                   0.0
# 1                         166                  1.0                   0.0
# 2                         208                  1.0                   1.0
# 3                         172                  1.0                   0.0
# 4                         177                  1.0                   0.0
# ...                       ...                  ...                   ...
# 171963                    NaN                  NaN                   NaN
# 171964                    NaN                  NaN                   NaN
# 171965                    NaN                  NaN                   NaN
# 171966                    NaN                  NaN                   NaN
# 171967                    NaN                  NaN                   NaN
#
#        Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                      151                     16                      5
# 1                      122                     22                      4
# 2                      163                     17                      3
# 3                      118                     13                      3
# 4                      118                     18                      4
# ...                    ...                    ...                    ...
# 171963                 NaN                    NaN                    NaN
# 171964                 NaN                    NaN                    NaN
# 171965                 NaN                    NaN                    NaN
# 171966                 NaN                    NaN                    NaN
# 171967                 NaN                    NaN                    NaN
#
#        Innings Batting Strike Rate  ... Innings Overs Bowled  \
# 0                           119.20  ...                  NaN
# 1                           140.16  ...                  NaN
# 2                           102.45  ...                  NaN
# 3                           137.28  ...                  NaN
# 4                           133.89  ...                  NaN
# ...                            ...  ...                  ...
# 171963                         NaN  ...                  DNB
# 171964                         NaN  ...                  DNB
# 171965                         NaN  ...                  DNB
# 171966                         NaN  ...                  DNB
# 171967                         NaN  ...                  DNB
#
#        Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded  \
# 0                      NaN                    NaN                   NaN
# 1                      NaN                    NaN                   NaN
# 2                      NaN                    NaN                   NaN
# 3                      NaN                    NaN                   NaN
# 4                      NaN                    NaN                   NaN
# ...                    ...                    ...                   ...
# 171963                 0.0                      -                     -
# 171964                 0.0                      -                     -
# 171965                 0.0                      -                     -
# 171966                 0.0                      -                     -
# 171967                 0.0                      -                     -
#
#        Innings Wickets Taken  4 Wickets  5 Wickets 10 Wickets  \
# 0                        NaN        NaN        NaN        NaN
# 1                        NaN        NaN        NaN        NaN
# 2                        NaN        NaN        NaN        NaN
# 3                        NaN        NaN        NaN        NaN
# 4                        NaN        NaN        NaN        NaN
# ...                      ...        ...        ...        ...
# 171963                     -        1.0        0.0        0.0
# 171964                     -        1.0        0.0        0.0
# 171965                     -        1.0        0.0        0.0
# 171966                     -        1.0        0.0        0.0
# 171967                     -        1.0        0.0        0.0
#
#        Innings Wickets Taken Buckets  Innings Economy Rate
# 0                                NaN                   NaN
# 1                                NaN                   NaN
# 2                                NaN                   NaN
# 3                                NaN                   NaN
# 4                                NaN                   NaN
# ...                              ...                   ...
# 171963                             -                     -
# 171964                             -                     -
# 171965                             -                     -
# 171966                             -                     -
# 171967                             -                     -
#
# [171968 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['Innings Player', 'Innings Runs Scored', 'Innings Runs Scored Num',
#        'Innings Minutes Batted', 'Innings Batted Flag', 'Innings Not Out Flag',
#        'Innings Balls Faced', 'Innings Boundary Fours',
#        'Innings Boundary Sixes', 'Innings Batting Strike Rate',
#        'Innings Number', 'Opposition', 'Ground', 'Innings Date', 'Country',
#        '50's', '100's', 'Innings Runs Scored Buckets', 'Innings Overs Bowled',
#        'Innings Bowled Flag', 'Innings Maidens Bowled',
#        'Innings Runs Conceded', 'Innings Wickets Taken', '4 Wickets',
#        '5 Wickets', '10 Wickets', 'Innings Wickets Taken Buckets',
#        'Innings Economy Rate'],
#       dtype='object')

# %%
df.head()
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0         JJ Roy                 180                     180
# 1       AD Hales                 171                     171
# 2       RA Smith                167*                     167
# 3         JJ Roy                 162                     162
# 4       DI Gower                 158                     158
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    151                  1.0                   0.0
# 1                    166                  1.0                   0.0
# 2                    208                  1.0                   1.0
# 3                    172                  1.0                   0.0
# 4                    177                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                 151                     16                      5
# 1                 122                     22                      4
# 2                 163                     17                      3
# 3                 118                     13                      3
# 4                 118                     18                      4
#
#   Innings Batting Strike Rate  ... Innings Overs Bowled Innings Bowled Flag  \
# 0                      119.20  ...                  NaN                 NaN
# 1                      140.16  ...                  NaN                 NaN
# 2                      102.45  ...                  NaN                 NaN
# 3                      137.28  ...                  NaN                 NaN
# 4                      133.89  ...                  NaN                 NaN
#
#   Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
#
#    4 Wickets  5 Wickets 10 Wickets Innings Wickets Taken Buckets  \
# 0        NaN        NaN        NaN                           NaN
# 1        NaN        NaN        NaN                           NaN
# 2        NaN        NaN        NaN                           NaN
# 3        NaN        NaN        NaN                           NaN
# 4        NaN        NaN        NaN                           NaN
#
#    Innings Economy Rate
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#             Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 171963  Samiullah Shinwari                 NaN                     NaN
# 171964       Asghar Afghan                 NaN                     NaN
# 171965   Najibullah Zadran                 NaN                     NaN
# 171966         Rahmat Shah                 NaN                     NaN
# 171967       Ikram Alikhil                 NaN                     NaN
#
#        Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 171963                    NaN                  NaN                   NaN
# 171964                    NaN                  NaN                   NaN
# 171965                    NaN                  NaN                   NaN
# 171966                    NaN                  NaN                   NaN
# 171967                    NaN                  NaN                   NaN
#
#        Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 171963                 NaN                    NaN                    NaN
# 171964                 NaN                    NaN                    NaN
# 171965                 NaN                    NaN                    NaN
# 171966                 NaN                    NaN                    NaN
# 171967                 NaN                    NaN                    NaN
#
#        Innings Batting Strike Rate  ... Innings Overs Bowled  \
# 171963                         NaN  ...                  DNB
# 171964                         NaN  ...                  DNB
# 171965                         NaN  ...                  DNB
# 171966                         NaN  ...                  DNB
# 171967                         NaN  ...                  DNB
#
#        Innings Bowled Flag Innings Maidens Bowled Innings Runs Conceded  \
# 171963                 0.0                      -                     -
# 171964                 0.0                      -                     -
# 171965                 0.0                      -                     -
# 171966                 0.0                      -                     -
# 171967                 0.0                      -                     -
#
#        Innings Wickets Taken  4 Wickets  5 Wickets 10 Wickets  \
# 171963                     -        1.0        0.0        0.0
# 171964                     -        1.0        0.0        0.0
# 171965                     -        1.0        0.0        0.0
# 171966                     -        1.0        0.0        0.0
# 171967                     -        1.0        0.0        0.0
#
#        Innings Wickets Taken Buckets  Innings Economy Rate
# 171963                             -                     -
# 171964                             -                     -
# 171965                             -                     -
# 171966                             -                     -
# 171967                             -                     -
#
# [5 rows x 28 columns]

# %%
df.isna().sum()
# Out:
# Innings Player                       0
# Innings Runs Scored              85984
# Innings Runs Scored Num          85984
# Innings Minutes Batted           85984
# Innings Batted Flag              85984
# Innings Not Out Flag             85984
# Innings Balls Faced              85984
# Innings Boundary Fours           85984
# Innings Boundary Sixes           85984
# Innings Batting Strike Rate      85984
# Innings Number                       0
# Opposition                           0
# Ground                               0
# Innings Date                         0
# Country                              0
# 50's                             85984
# 100's                            85984
# Innings Runs Scored Buckets      85984
# Innings Overs Bowled             85984
# Innings Bowled Flag              85984
# Innings Maidens Bowled           85984
# Innings Runs Conceded            85984
# Innings Wickets Taken            85984
# 4 Wickets                        85984
# 5 Wickets                        85984
# 10 Wickets                       85984
# Innings Wickets Taken Buckets    85984
# Innings Economy Rate             85984
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171968 entries, 0 to 171967
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Innings Player                 171968 non-null  object
#  1   Innings Runs Scored            85984 non-null   object
#  2   Innings Runs Scored Num        85984 non-null   object
#  3   Innings Minutes Batted         85984 non-null   object
#  4   Innings Batted Flag            85984 non-null   float64
#  5   Innings Not Out Flag           85984 non-null   float64
#  6   Innings Balls Faced            85984 non-null   object
#  7   Innings Boundary Fours         85984 non-null   object
#  8   Innings Boundary Sixes         85984 non-null   object
#  9   Innings Batting Strike Rate    85984 non-null   object
#  10  Innings Number                 171968 non-null  object
#  11  Opposition                     171968 non-null  object
#  12  Ground                         171968 non-null  object
#  13  Innings Date                   171968 non-null  object
#  14  Country                        171968 non-null  object
#  15  50's                           85984 non-null   float64
#  16  100's                          85984 non-null   float64
#  17  Innings Runs Scored Buckets    85984 non-null   object
#  18  Innings Overs Bowled           85984 non-null   object
#  19  Innings Bowled Flag            85984 non-null   float64
#  20  Innings Maidens Bowled         85984 non-null   object
#  21  Innings Runs Conceded          85984 non-null   object
#  22  Innings Wickets Taken          85984 non-null   object
#  23  4 Wickets                      85984 non-null   float64
#  24  5 Wickets                      85984 non-null   float64
#  25  10 Wickets                     85984 non-null   float64
#  26  Innings Wickets Taken Buckets  85984 non-null   object
#  27  Innings Economy Rate           85984 non-null   object
# dtypes: float64(8), object(20)
# memory usage: 36.7+ MB

# %%
df_batting =df[['Innings Player','Innings Runs Scored Num','Innings Minutes Batted','Innings Batted Flag','Innings Balls Faced','Innings Boundary Fours','Innings Boundary Sixes','Innings Batting Strike Rate']]
df_batting
# Out:
#             Innings Player Innings Runs Scored Num Innings Minutes Batted  \
# 0                   JJ Roy                     180                    151
# 1                 AD Hales                     171                    166
# 2                 RA Smith                     167                    208
# 3                   JJ Roy                     162                    172
# 4                 DI Gower                     158                    177
# ...                    ...                     ...                    ...
# 171963  Samiullah Shinwari                     NaN                    NaN
# 171964       Asghar Afghan                     NaN                    NaN
# 171965   Najibullah Zadran                     NaN                    NaN
# 171966         Rahmat Shah                     NaN                    NaN
# 171967       Ikram Alikhil                     NaN                    NaN
#
#         Innings Batted Flag Innings Balls Faced Innings Boundary Fours  \
# 0                       1.0                 151                     16
# 1                       1.0                 122                     22
# 2                       1.0                 163                     17
# 3                       1.0                 118                     13
# 4                       1.0                 118                     18
# ...                     ...                 ...                    ...
# 171963                  NaN                 NaN                    NaN
# 171964                  NaN                 NaN                    NaN
# 171965                  NaN                 NaN                    NaN
# 171966                  NaN                 NaN                    NaN
# 171967                  NaN                 NaN                    NaN
#
#        Innings Boundary Sixes Innings Batting Strike Rate
# 0                           5                      119.20
# 1                           4                      140.16
# 2                           3                      102.45
# 3                           3                      137.28
# 4                           4                      133.89
# ...                       ...                         ...
# 171963                    NaN                         NaN
# 171964                    NaN                         NaN
# 171965                    NaN                         NaN
# 171966                    NaN                         NaN
# 171967                    NaN                         NaN
#
# [171968 rows x 8 columns]

# %%
df_batting = df_batting[~df_batting['Innings Runs Scored Num'].isin(['-'])]
df_batting = df_batting[~df_batting['Innings Minutes Batted'].isin(['-'])]
df_batting = df_batting[~df_batting['Innings Batted Flag'].isin(['-'])]
df_batting = df_batting[~df_batting['Innings Balls Faced'].isin(['-'])]
df_batting = df_batting[~df_batting['Innings Boundary Fours'].isin(['-'])]
df_batting = df_batting[~df_batting['Innings Boundary Sixes'].isin(['-'])]
df_batting = df_batting[~df_batting['Innings Batting Strike Rate'].isin(['-'])]

# %%
df_batting = df_batting.dropna()

# %%
df_batting['Innings Runs Scored Num'] = df_batting['Innings Runs Scored Num'].astype(int)
df_batting['Innings Minutes Batted'] = df_batting['Innings Minutes Batted'].astype(int)
df_batting['Innings Balls Faced'] = df_batting['Innings Balls Faced'].astype(int)
df_batting['Innings Boundary Fours'] = df_batting['Innings Boundary Fours'].astype(int)
df_batting['Innings Boundary Sixes'] = df_batting['Innings Boundary Sixes'].astype(int)
df_batting['Innings Batting Strike Rate'] = df_batting['Innings Batting Strike Rate'].astype(float)

# %%
df_compare=df_batting[(df_batting['Innings Player']=='RG Sharma')|(df_batting['Innings Player']=='SR Tendulkar')|(df_batting['Innings Player']=='V Kohli')|(df_batting['Innings Player'] == 'MS Dhoni')|(df_batting['Innings Player'] == 'Yuvraj Singh')]
df_compare
# Out:
#       Innings Player  Innings Runs Scored Num  Innings Minutes Batted  \
# 42755      RG Sharma                      264                     225
# 42757      RG Sharma                      209                     222
# 42758      RG Sharma                      208                     212
# 42759   SR Tendulkar                      200                     226
# 42760   SR Tendulkar                      186                     221
# ...              ...                      ...                     ...
# 50772       MS Dhoni                        0                       2
# 50777        V Kohli                        0                       5
# 50778      RG Sharma                        0                       4
# 50782        V Kohli                        0                       7
# 50789      RG Sharma                        0                       4
#
#        Innings Batted Flag  Innings Balls Faced  Innings Boundary Fours  \
# 42755                  1.0                  173                      33
# 42757                  1.0                  158                      12
# 42758                  1.0                  153                      13
# 42759                  1.0                  147                      25
# 42760                  1.0                  150                      20
# ...                    ...                  ...                     ...
# 50772                  1.0                    3                       0
# 50777                  1.0                    5                       0
# 50778                  1.0                    3                       0
# 50782                  1.0                    4                       0
# 50789                  1.0                    6                       0
#
#        Innings Boundary Sixes  Innings Batting Strike Rate
# 42755                       9                       152.60
# 42757                      16                       132.27
# 42758                      12                       135.94
# 42759                       3                       136.05
# 42760                       3                       124.00
# ...                       ...                          ...
# 50772                       0                         0.00
# 50777                       0                         0.00
# 50778                       0                         0.00
# 50782                       0                         0.00
# 50789                       0                         0.00
#
# [1309 rows x 8 columns]

# %%
df_compare.isnull().sum()
# Out:
# Innings Player                 0
# Innings Runs Scored Num        0
# Innings Minutes Batted         0
# Innings Balls Faced            0
# Innings Boundary Fours         0
# Innings Boundary Sixes         0
# Innings Batting Strike Rate    0
# dtype: int64

# %%
player=df_compare.drop(['Innings Balls Faced','Innings Minutes Batted'],axis=1)
sns.pairplot(b,hue='Innings Player')

# %%
import seaborn as sns
df_compare = df_compare.drop('Innings Minutes Batted', axis=1)
sns.heatmap(df_compare.corr(), annot=True)
